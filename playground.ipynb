# %%
import pandas as pd

# %%
df = pd.read_parquet('salida_enigh2024/enigh2024_persona.parquet')

# %%
df.shape
# Out:
# (308598, 303)

# %%
df.head()
# Out:
#      folioviv foliohog numren parentesco sexo  edad madre_hog madre_id  \
# 0  0100001901        1     01        101    1    32         2     None
# 1  0100001901        1     02        201    2    24         2     None
# 2  0100001901        1     03        301    2     5         1       02
# 3  0100001901        1     04        301    1     2         1       02
# 4  0100001902        1     01        101    1    48         2     None
#
#   padre_hog padre_id  ... es_perceptor es_ocupado ing_tri_sm grupo_edad neg_n  \
# 0         2     None  ...         True       True   1.172263      30-39   NaN
# 1         2     None  ...         True       True   0.463578      20-29   NaN
# 2         1       01  ...        False      False        NaN       0-11   NaN
# 3         1       01  ...        False      False        NaN       0-11   NaN
# 4         2     None  ...         True       True   0.844193      40-49   NaN
#
#   neg_ing_tri neg_ventas_tri neg_gasto_tri neg_personal neg_tiene
# ...
